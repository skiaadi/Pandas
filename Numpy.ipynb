# %% [markdown]
# <a href="https://colab.research.google.com/github/skiaadi/Pandas/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment-8
# #Numpy
# ##Aadi Havele
# ##25070123001

# %%
import numpy as np

a=np.array([10,20,30,40])
b=np.array([[1,2,3],[4,5,6]])
print(a,b)
# Out:
# [10 20 30 40] [[1 2 3]
#  [4 5 6]]

# %%
a.ndim
b.ndim
# Out:
# 2

# %%
a.shape
b.shape
# Out:
# (2, 3)

# %%
a.dtype
b.dtype
# Out:
# dtype('int64')

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.median(a)
# Out:
# np.float64(25.0)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.sum(a)
# Out:
# np.int64(100)
